# %%
# !pip install pytrends
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pytrends
#   Downloading pytrends-4.8.0.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: requests>=2.0 in c:\users\esmeekramer\appdata\roaming\python\python310\site-packages (from pytrends) (2.27.1)
# Collecting pandas>=0.25
#   Downloading pandas-1.4.1-cp310-cp310-win_amd64.whl (10.6 MB)
#      --------------------------------------- 10.6/10.6 MB 14.6 MB/s eta 0:00:00
# Collecting lxml
#   Downloading lxml-4.8.0-cp310-cp310-win_amd64.whl (3.6 MB)
#      ---------------------------------------- 3.6/3.6 MB 21.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.0 in c:\users\esmeekramer\appdata\roaming\python\python310\site-packages (from pandas>=0.25->pytrends) (1.22.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\esmeekramer\appdata\roaming\python\python310\site-packages (from pandas>=0.25->pytrends) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\esmeekramer\appdata\roaming\python\python310\site-packages (from pandas>=0.25->pytrends) (2021.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\esmeekramer\appdata\roaming\python\python310\site-packages (from requests>=2.0->pytrends) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\esmeekramer\appdata\roaming\python\python310\site-packages (from requests>=2.0->pytrends) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\esmeekramer\appdata\roaming\python\python310\site-packages (from requests>=2.0->pytrends) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\esmeekramer\appdata\roaming\python\python310\site-packages (from requests>=2.0->pytrends) (2021.10.8)
# Requirement already satisfied: six>=1.5 in c:\users\esmeekramer\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.1->pandas>=0.25->pytrends) (1.16.0)
# Using legacy 'setup.py install' for pytrends, since package 'wheel' is not installed.
# Installing collected packages: lxml, pandas, pytrends
#   Running setup.py install for pytrends: started
#   Running setup.py install for pytrends: finished with status 'done'
# Successfully installed lxml-4.8.0 pandas-1.4.1 pytrends-4.8.0

# %%
import pandas as pd                        
from pytrends.request import TrendReq
pytrend = TrendReq()

# %%
print(pytrend)
# Out:
# <pytrends.request.TrendReq object at 0x000002042CE9C700>

# %%
pytrend.build_payload(kw_list=['Taylor Swift'])
# Interest by Region
df = pytrend.interest_by_region()
df.head(10)
# Out:
#                    Taylor Swift
# geoName
# Afghanistan                   0
# Albania                       0
# Algeria                       0
# American Samoa                0
# Andorra                       0
# Angola                        0
# Anguilla                      0
# Antarctica                    0
# Antigua & Barbuda             0
# Argentina                    22

# %% [markdown]
# The values are calculated on a scale from 0 to 100, where 100 is the location with the most popularity as a fraction of total searches in that location, a value of 50 indicates a location which is half as popular. A value of 0 indicates a location where there was not enough data for this term.

# %%
df.reset_index().plot(x='geoName', y='Taylor Swift', figsize=(120, 10), kind ='bar')
# Out:
# <AxesSubplot:xlabel='geoName'>

# %%
# Get Google Hot Trends data
df = pytrend.trending_searches(pn='netherlands')
print(df)
# Out:
#                          0
# 0              Thomas Krol
# 1               Connexxion
# 2   Horizon Forbidden West
# 3                Eileen Gu
# 4                  Valieva
# 5             Felicity Ace
# 6                     KNVB
# 7                      PSV
# 8                Barcelona
# 9              Van Zundert
# 10                 Vitesse
# 11          Andre van Duin
# 12            Michael Masi
# 13                    Beau
# 14             Jody Lukoki
# 15                Dortmund
# 16                      AZ
# 17             Laverne Cox
# 18                    Masi
# 19           Johnny de Mol

# %%
# Get Google Keyword Suggestions
keywords = pytrend.suggestions(keyword='storm')
df = pd.DataFrame(keywords)
df.drop(columns= 'mid')   # This column makes no sense
# Out:
#           title                               type
# 0        Arashi                           Boy band
# 1         Storm                              Topic
# 2  Thunderstorm                      Disaster type
# 3    Toni Storm  New Zealand professional wrestler
# 4         Storm                      Marvel Comics

# %%
pytrend.build_payload(kw_list=['omgevingsdienst'])
#pytrend.build_payload(kw_list=['Coronavirus'])

# %%
# Related Queries, returns a dictionary of dataframes
related_queries = pytrend.related_queries()
related_queries.values()
# Out:
# dict_values([{'top':                                      query  value
# 0                  omgevingsdienst brabant    100
# 1     omgevingsdienst noordzeekanaalgebied     92
# 2                     noordzeekanaalgebied     92
# 3               omgevingsdienst haaglanden     68
# 4                               haaglanden     68
# 5             omgevingsdienst rivierenland     63
# 6                omgevingsdienst groningen     57
# 7        omgevingsdienst zuid holland zuid     50
# 8                   omgevingsdienst ijmond     47
# 9             omgevingsdienst west holland     45
# 10           omgevingsdienst brabant noord     44
# 11          omgevingsdienst midden holland     39
# 12     omgevingsdienst noord holland noord     35
# 13           omgevingsdienst noord holland     35
# 14     omgevingsdienst midden west brabant     34
# 15               omgevingsdienst flevoland     34
# 16              omgevingsdienst achterhoek     28
# 17               omgevingsdienst de vallei     28
# 18                  omgevingsdienst twente     27
# 19  omgevingsdienst midden en west brabant     26
# 20              omgevingsdienst ijsselland     24
# 21        omgevingsdienst zuidoost brabant     20
# 22                     omgevingsvergunning     17
# 23           omgevingsdienst regio utrecht     17
# 24          omgevingsdienst noordzeekanaal     17, 'rising':                                   query  value
# 0                 wet natuurbescherming  43300
# 1                                mozard  17250
# 2                omgevingsdienst twente   2550
# 3            omgevingsdienst ijsselland    600
# 4                   ruimtelijke plannen    250
# 5            hoogheemraadschap rijnland    170
# 6                                 funda    150
# 7   omgevingsdienst noord holland noord    120
# 8         omgevingsdienst noord holland    120
# 9                          omgevingswet    120
# 10                  omgevingsvergunning     60
# 11               omgevingsdienst ijmond     50}])

# %%
# Related Topics, returns a dictionary of dataframes
related_topic = pytrend.related_topics()
related_topic.values()
#related_topic.drop(columns='mid')
# Out:
# dict_values([{'rising':     value formattedValue                                            link  \
# 0   94700       Breakout      /trends/explore?q=/m/030yg_&date=today+5-y
# 1   46450       Breakout       /trends/explore?q=/m/0phtk&date=today+5-y
# 2   39550       Breakout      /trends/explore?q=/m/016wqg&date=today+5-y
# 3   20600       Breakout       /trends/explore?q=/m/059qw&date=today+5-y
# 4   18900       Breakout     /trends/explore?q=/m/04zxzzy&date=today+5-y
# 5   18900       Breakout      /trends/explore?q=/m/012bnw&date=today+5-y
# 6   17150       Breakout  /trends/explore?q=/g/11bc5wl6z5&date=today+5-y
# 7   17150       Breakout      /trends/explore?q=/m/04qb5p&date=today+5-y
# 8   17150       Breakout   /trends/explore?q=/g/1z2cr_jg8&date=today+5-y
# 9   15400       Breakout     /trends/explore?q=/m/0nblvpz&date=today+5-y
# 10  13700       Breakout    /trends/explore?q=/g/120_gdhy&date=today+5-y
# 11  13700       Breakout      /trends/explore?q=/m/03n2_q&date=today+5-y
# 12  11950       Breakout      /trends/explore?q=/m/01p0hr&date=today+5-y
# 13  11950       Breakout     /trends/explore?q=/m/03nnjx5&date=today+5-y
# 14  10250       Breakout     /trends/explore?q=/m/02vxhtt&date=today+5-y
# 15   6800       Breakout  /trends/explore?q=/g/11c5wl1xxj&date=today+5-y
# 16   4600        +4,600%      /trends/explore?q=/m/063p10&date=today+5-y
# 17   1150        +1,150%     /trends/explore?q=/m/0bmc1j8&date=today+5-y
# 18    750          +750%  /trends/explore?q=/g/11bc5nww36&date=today+5-y
# 19    700          +700%       /trends/explore?q=/m/0w0n4&date=today+5-y
#
#         topic_mid                          topic_title  \
# 0       /m/030yg_                          Environment
# 1        /m/0phtk                   Nature maintenance
# 2       /m/016wqg                            Authority
# 3        /m/059qw                            North Sea
# 4      /m/04zxzzy  Per- and polyfluoroalkyl substances
# 5       /m/012bnw                             Westland
# 6   /g/11bc5wl6z5                         Geldermalsen
# 7       /m/04qb5p                            Inspector
# 8    /g/1z2cr_jg8        Netherlands Enterprise Agency
# 9      /m/0nblvpz                              Manager
# 10    /g/120_gdhy                                Vught
# 11      /m/03n2_q                     Home improvement
# 12      /m/01p0hr                                 Oath
# 13     /m/03nnjx5                                  Net
# 14     /m/02vxhtt                          Berg en Dal
# 15  /g/11c5wl1xxj            Indeed - Amsterdam Office
# 16      /m/063p10                               Twente
# 17     /m/0bmc1j8                 Collective agreement
# 18  /g/11bc5nww36                               Budget
# 19       /m/0w0n4                                Hoorn
#
#                          topic_type
# 0                    Field of study
# 1                             Topic
# 2                             Topic
# 3                               Sea
# 4                             Topic
# 5   Municipality in the Netherlands
# 6                             Topic
# 7                             Topic
# 8                           Company
# 9                        Profession
# 10                            Topic
# 11                            Topic
# 12                            Topic
# 13                        Economics
# 14       Village in the Netherlands
# 15                            Topic
# 16        Region in the Netherlands
# 17                            Topic
# 18                            Topic
# 19          City in the Netherlands  , 'top':     value formattedValue  hasData  \
# 0     100            100     True
# 1      40             40     True
# 2      39             39     True
# 3      26             26     True
# 4      25             25     True
# 5      23             23     True
# 6      22             22     True
# 7      20             20     True
# 8      20             20     True
# 9      20             20     True
# 10     19             19     True
# 11     18             18     True
# 12     15             15     True
# 13     14             14     True
# 14     14             14     True
# 15     14             14     True
# 16     13             13     True
# 17     12             12     True
# 18     12             12     True
#
#                                               link      topic_mid  \
# 0        /trends/explore?q=/m/059j2&date=today+5-y       /m/059j2
# 1        /trends/explore?q=/m/0fcrg&date=today+5-y       /m/0fcrg
# 2   /trends/explore?q=/g/11b6wd7sb9&date=today+5-y  /g/11b6wd7sb9
# 3   /trends/explore?q=/g/11b7xjjlz3&date=today+5-y  /g/11b7xjjlz3
# 4      /trends/explore?q=/m/0gh8lzg&date=today+5-y     /m/0gh8lzg
# 5   /trends/explore?q=/g/11b6gh6_4d&date=today+5-y  /g/11b6gh6_4d
# 6   /trends/explore?q=/g/11cn3w0y5n&date=today+5-y  /g/11cn3w0y5n
# 7     /trends/explore?q=/g/121k2p3x&date=today+5-y    /g/121k2p3x
# 8        /trends/explore?q=/m/07371&date=today+5-y       /m/07371
# 9        /trends/explore?q=/m/0d8rs&date=today+5-y       /m/0d8rs
# 10  /trends/explore?q=/g/11b7k3tgty&date=today+5-y  /g/11b7k3tgty
# 11   /trends/explore?q=/g/1ptxrm7yc&date=today+5-y   /g/1ptxrm7yc
# 12       /trends/explore?q=/m/0fqyc&date=today+5-y       /m/0fqyc
# 13  /trends/explore?q=/g/11cmyln741&date=today+5-y  /g/11cmyln741
# 14    /trends/explore?q=/g/1vcjlhbj&date=today+5-y    /g/1vcjlhbj
# 15       /trends/explore?q=/m/05g2b&date=today+5-y       /m/05g2b
# 16       /trends/explore?q=/m/0bt5w&date=today+5-y       /m/0bt5w
# 17  /trends/explore?q=/g/11cn7wjxbp&date=today+5-y  /g/11cn7wjxbp
# 18       /trends/explore?q=/m/0d9s5&date=today+5-y       /m/0d9s5
#
#                                           topic_title  \
# 0                                         Netherlands
# 1                                       North Brabant
# 2            Environment Service Noordzeekanaalgebied
# 3                      Environment Service Haaglanden
# 4                                          Haaglanden
# 5                    Environment Service Rivierenland
# 6                    Environment Department Groningen
# 7                             Recruitment advertising
# 8                                       South Holland
# 9                                           Groningen
# 10                  Environment Service North Brabant
# 11    Environment Department Central and West Brabant
# 12                                      North Holland
# 13                     Omgevingsdienst Regio Nijmegen
# 14  Regional Implementation Service Noord-Holland ...
# 15                                           Nijmegen
# 16                                          Flevoland
# 17                   Omgevingsdienst Zuidoost-Brabant
# 18                                            Utrecht
#
#                                            topic_type
# 0                                   Country in Europe
# 1                                      Dutch province
# 2           Government office in Zaandam, Netherlands
# 3         Government office in the Hague, Netherlands
# 4                           Region in the Netherlands
# 5              Government office in Tiel, Netherlands
# 6           Government office in Veendam, Netherlands
# 7                                               Topic
# 8                                           Provincie
# 9                                            Province
# 10  Government office in 's-Hertogenbosch, Netherl...
# 11          Government office in Tilburg, Netherlands
# 12                                          Provincie
# 13         Government office in Nijmegen, Netherlands
# 14                 Municipality in Hoorn, Netherlands
# 15                    Municipality in the Netherlands
# 16                                          Provincie
# 17        Government office in Eindhoven, Netherlands
# 18                            City in the Netherlands  }])

# %%
pytrend.realtime_trending_searches(pn='NL')
# Out:
#                                                  title  \
# 0                                   Rotterdam, Roofing
# 1                                            Amsterdam
# 2                              Scheveningen, The Hague
# 3                     ADO Den Haag, Cars Jeans Stadion
# 4                                             Drachten
# ..                                                 ...
# 156                                               Jori
# 157       James Gunn, John Cena, Peacemaker, DC Comics
# 158                                        Afsluitdijk
# 159  Dutch Food and Consumer Product Safety Authori...
# 160                                      Honselersdijk
#
#                                            entityNames
# 0                                 [Rotterdam, Roofing]
# 1                                          [Amsterdam]
# 2                            [Scheveningen, The Hague]
# 3                   [ADO Den Haag, Cars Jeans Stadion]
# 4                                           [Drachten]
# ..                                                 ...
# 156                                             [Jori]
# 157     [James Gunn, John Cena, Peacemaker, DC Comics]
# 158                                      [Afsluitdijk]
# 159  [Dutch Food and Consumer Product Safety Author...
# 160                                    [Honselersdijk]
#
# [161 rows x 2 columns]

# %%
date = '2022'
top_charts = pytrend.top_charts(date, hl='en-US', tz=300, geo='GLOBAL')
print(top_charts)
# Out:
# None
